# %%
import seaborn as sb
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
print(np.__version__)
# Out:
# 1.11.3

# %%
print(sb.__version__)
# Out:
# 0.7.1

# %%
#seabond is used for statical data visulisation
#seabond directly wonk on pandas data
#seabond is used for categorical data and nominal data
#linear plot for num data,categorical data for ordinal and nominal data(bar plot,count ,factor ,swarmplot,categorical plot)

# %%
mydata=pd.read_excel(r"C:\Users\dell\Desktop\ML\DataSets-master\PokemonData.xlsx")

# %%
mydata
# Out:
#            Name    Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# NaN   Bulbasaur     Grass   Poison    318   45      49       49       65
# NaN     Ivysaur     Grass   Poison    405   60      62       63       80
# NaN    Venusaur     Grass   Poison    525   80      82       83      100
# NaN  Charmander      Fire      NaN    309   39      52       43       60
# NaN  Charmeleon      Fire      NaN    405   58      64       58       80
# NaN   Charizard      Fire   Flying    534   78      84       78      109
# NaN    Squirtle     Water      NaN    314   44      48       65       50
# NaN   Wartortle     Water      NaN    405   59      63       80       65
# NaN   Blastoise     Water      NaN    530   79      83      100       85
# NaN    Caterpie       Bug      NaN    195   45      30       35       20
# NaN     Metapod       Bug      NaN    205   50      20       55       25
# NaN  Butterfree       Bug   Flying    395   60      45       50       90
# ...

# %%
mydata.head(1)
# Out:
#           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# NaN  Bulbasaur  Grass  Poison    318  45      49       49       65       65
#
#      Speed  Stage Legendary
# NaN     45      1     False

# %%
sb.lmplot(x='Attack',y='Defense',data=mydata,fit_reg=False,scatter_kws={"color":"red"},hue="Stage",markers=["*",">","<"])

# %%
sb.countplot(x='Type 1',data=mydata)
plt.xticks(rotation=45)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-deed355b2f4e> in <module>()
#       1 sb.countplot(x='Type 1',data=mydata)
# ----> 2 plt.xticks(rotation=45)
#
# AttributeError: module 'matplotlib' has no attribute 'xticks'
