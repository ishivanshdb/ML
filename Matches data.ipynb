# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
data=pd.read_csv(r"C:\Users\dell\Desktop\ML\DataSets-master\matches.csv")

# %%
data
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5      6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7      8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 9     10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10    11    2017        Kolkata  2017-04-13              Kings XI Punjab
# 11    12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %%
len(data)
# Out:
# 636

# %%
season=data['season']

# %%
import numpy as np

# %%
len(np.unique(season))
# Out:
# 10

# %%
won=data['win_by_runs'].max()

# %%
won
# Out:
# 146

# %%
name=data[data['win_by_runs']==146]

# %%
name
# Out:
#     id  season   city        date           team1             team2  \
# 43  44    2017  Delhi  2017-05-06  Mumbai Indians  Delhi Daredevils
#
#          toss_winner toss_decision  result  dl_applied          winner  \
# 43  Delhi Daredevils         field  normal           0  Mumbai Indians
#
#     win_by_runs  win_by_wickets player_of_match             venue  \
# 43          146               0     LMP Simmons  Feroz Shah Kotla
#
#         umpire1    umpire2  umpire3
# 43  Nitin Menon  CK Nandan      NaN

# %%
team=name['winner']

# %%
team
# Out:
# 43    Mumbai Indians
# Name: winner, dtype: object

# %%
data.iloc[data.win_by_runs.idxmax()]["winner"]
# Out:
# 'Mumbai Indians'

# %%
data.iloc[data.win_by_wickets.idxmax()]["winner"]
# Out:
# 'Kolkata Knight Riders'

# %%
data.iloc[data.win_by_runs.idxmin()]["winner"]
# Out:
# 'Rising Pune Supergiant'

# %%
data.iloc[data[data['win_by_wickets'].ge(1)].win_by_wickets.idxmin()]['winner']
# Out:
# 'Kolkata Knight Riders'

# %%
data.iloc[data[data['win_by_runs'].ge(1)].win_by_runs.idxmin()]['winner']
# Out:
# 'Mumbai Indians'

# %%
sb.countplot(x='season',data=data)

# %%
sb.countplot(x='player_of_match',data=data)

# %%
man_of_match=data.player_of_match

# %%
man_of_match.iloc[-1]
# Out:
# 'BCJ Cutting'

# %%
len(man_of_match)
# Out:
# 636

# %%
len(man_of_match.unique())
# Out:
# 202

# %%
data["player_of_match"].value_counts()
# Out:
# CH Gayle             18
# YK Pathan            16
# DA Warner            15
# AB de Villiers       15
# RG Sharma            14
# SK Raina             14
# G Gambhir            13
# MS Dhoni             13
# AM Rahane            12
# MEK Hussey           12
# DR Smith             11
# V Kohli              11
# V Sehwag             11
# JH Kallis            10
# SR Watson            10
# SE Marsh              9
# KA Pollard            9
# A Mishra              9
# SR Tendulkar          8
# RA Jadeja             7
# AC Gilchrist          7
# RV Uthappa            7
# AT Rayudu             7
# AD Russell            6
# Harbhajan Singh       6
# A Nehra               6
# BJ Hodge              6
# UT Yadav              6
# M Vijay               6
# SP Narine             6
#                      ..
# TL Suman              1
# M Kartik              1
# JDP Oram              1
# KS Williamson         1
# A Chandila            1
# MS Bisla              1
# Z Khan                1
# ...

# %%
data["player_of_match"].value_counts()[:10]
#for top 10
# Out:
# CH Gayle          18
# YK Pathan         16
# DA Warner         15
# AB de Villiers    15
# RG Sharma         14
# SK Raina          14
# G Gambhir         13
# MS Dhoni          13
# AM Rahane         12
# MEK Hussey        12
# Name: player_of_match, dtype: int64

# %%
mof=data["player_of_match"].value_counts()

# %%
sb.barplot(x=mof.index,y=mof.values)
plt.xticks(rotation=45)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-89-940d225f4c12> in <module>()
#       1 sb.barplot(x=mof.index,y=mof.values)
# ----> 2 plt.xticks(rotation=45)
#
# AttributeError: module 'matplotlib' has no attribute 'xticks'
