# %%
import pandas as pd

# %%
mydata=pd.read_csv(r"C:\Users\dell\Desktop\ML\DataSets-master\Housing_Data.csv")

# %%
mydata
# Out:
#      Unnamed: 0     price  lotsize  bedrooms  bathrms  stories driveway  \
# 0             1   42000.0     5850         3        1        2      yes
# 1             2   38500.0     4000         2        1        1      yes
# 2             3   49500.0     3060         3        1        1      yes
# 3             4   60500.0     6650         3        1        2      yes
# 4             5   61000.0     6360         2        1        1      yes
# 5             6   66000.0     4160         3        1        1      yes
# 6             7   66000.0     3880         3        2        2      yes
# 7             8   69000.0     4160         3        1        3      yes
# 8             9   83800.0     4800         3        1        1      yes
# 9            10   88500.0     5500         3        2        4      yes
# 10           11   90000.0     7200         3        2        1      yes
# 11           12   30500.0     3000         2        1        1       no
# ...

# %%
X_input=mydata["Unnamed","lotsise","bedrooms","stories","driveway","recroom","fullbase","gashw","airco","garagepl","prefarea"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\dell\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: ('Unnamed', 'lotsise', 'bedrooms', 'stories', 'driveway', 'recroom', 'fullbase', 'gashw', 'airco', 'garagepl', 'prefarea')
#
# During handling of the above exception, another exception occurred:
#
# ...
