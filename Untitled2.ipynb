# %%
import pandas as pd

# %%
mydata=pd.read_csv(r"C:\Users\dell\Desktop\ML\DataSets-master\Data_MVLR.csv")

# %%
mydata
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00            3571            1976                         0.525
# 1         9.00            4092            1250                         0.572
# 2         9.00            3865            1586                         0.580
# 3         7.50            4870            2351                         0.529
# 4         8.00            4399             431                         0.544
# 5        10.00            5342            1333                         0.571
# 6         8.00            5319           11868                         0.451
# 7         8.00            5126            2138                         0.553
# 8         8.00            4447            8577                         0.529
# 9         7.00            4512            8507                         0.552
# 10        8.00            4391            5939                         0.530
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
x_input=mydata.drop("Petrol_Consumption",axis=1)
x_input
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)
# 0         9.00            3571            1976                         0.525
# 1         9.00            4092            1250                         0.572
# 2         9.00            3865            1586                         0.580
# 3         7.50            4870            2351                         0.529
# 4         8.00            4399             431                         0.544
# 5        10.00            5342            1333                         0.571
# 6         8.00            5319           11868                         0.451
# 7         8.00            5126            2138                         0.553
# 8         8.00            4447            8577                         0.529
# 9         7.00            4512            8507                         0.552
# 10        8.00            4391            5939                         0.530
# ...

# %%
y_out=mydata["Petrol_Consumption"]

# %%
xx_input=x_input.values.reshape(-1,4)

# %%
yy_out=y_out.values.reshape(-1,1)

# %%
mydata.keys()
# Out:
# Index(['Petrol_tax', 'Average_income', 'Paved_Highways',
#        'Population_Driver_licence(%)', 'Petrol_Consumption'],
#       dtype='object')

# %%
xx_input.shape
# Out:
# (48, 4)

# %%
yy_out.shape
# Out:
# (48, 1)

# %%
x_train=xx_input[:40]
x_test=xx_input[40:]
y_train=yy_out[:40]
y_test=yy_out[40:]

# %%
from sklearn.linear_model import LinearRegression

# %%
teacher=LinearRegression()

# %%
learner=teacher.fit(x_train,y_train)

# %%
yp=learner.predict(x_test)
ypp=list(yp)
yaa=list(y_test)
xx_test=list(x_test)

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
np.sqrt(mean_squared_error(y_test,yp))
# Out:
# 57.481259417417661
