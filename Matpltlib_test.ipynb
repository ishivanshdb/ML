# %%
from matplotlib import pyplot as plt

# %%
X=[1,2,3,4,5,6,7,8]
Y=[2,3,5,6,6,8,9,10]
Z=[3,5,6,0,7,9,11,12]

# %%
#for linear regression we need descreate plot

# %%
plt.plot(X,Y,'r')
plt.show()

# %%
plt.plot(X,Y,'bo')
plt.show()

# %%
plt.plot(X,Y,'b>')
plt.show()

# %%
plt.plot(X,Z,"r*")
plt.show()

# %%
plt.plot(X,Y,'b>')
plt.plot(X,Z,'r*')
plt.xlabel("Input")
plt.ylabel("Output")
plt.legend(["Y","Z"])
plt.title("xvsY")
plt.show()

# %%
from matplotlib import pyplot as plt
