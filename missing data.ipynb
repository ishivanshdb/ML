# %%
import pandas as pd

# %%
mydata=pd.read_csv(r"C:\Users\dell\Desktop\ML\DataSets-master\uforeports.csv")

# %%
mydata.head(2)
# Out:
#    Unnamed: 0         City Colors Reported Shape Reported State  \
# 0           0       Ithaca             NaN       TRIANGLE    NY
# 1           1  Willingboro             NaN          OTHER    NJ
#
#               Time
# 0   6/1/1930 22:00
# 1  6/30/1930 20:00

# %%
mydata.isnull().sum()
# Out:
# Unnamed: 0             0
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
mydata.shape
# Out:
# (18241, 6)

# %%
mydata.notnull().sum()
# Out:
# Unnamed: 0         18241
# City               18216
# Colors Reported     2882
# Shape Reported     15597
# State              18241
# Time               18241
# dtype: int64

# %%
# to delete null data
mydata.dropna().shape
# Out:
# (2486, 6)

# %%
mydata.dropna(how='any')
# Out:
#        Unnamed: 0               City Colors Reported Shape Reported State  \
# 12             12             Belton             RED         SPHERE    SC
# 19             19         Bering Sea             RED          OTHER    AK
# 36             36         Portsmouth             RED      FORMATION    VA
# 44             44          Blairsden           GREEN         SPHERE    CA
# 82             82           San Jose            BLUE        CHEVRON    CA
# 84             84            Modesto            BLUE           DISK    CA
# 91             91             Scipio             RED         SPHERE    IN
# 111           111       Tarrant City          ORANGE         CIRCLE    AL
# 129           129               Napa           GREEN           DISK    CA
# 138           138      Coeur d'Alene          ORANGE          CIGAR    ID
# 152           152             Irving            BLUE           DISK    KS
# 157           157         Greenville           GREEN           DISK    MS
# ...

# %%
mydata.dropna(how='any').shape
# Out:
# (2486, 6)

# %%
mydata.dropna(thresh=5)
#delete null data if it occurs in particular 5 columns
# Out:
#        Unnamed: 0                  City Colors Reported Shape Reported State  \
# 0               0                Ithaca             NaN       TRIANGLE    NY
# 1               1           Willingboro             NaN          OTHER    NJ
# 2               2               Holyoke             NaN           OVAL    CO
# 3               3               Abilene             NaN           DISK    KS
# 4               4  New York Worlds Fair             NaN          LIGHT    NY
# 5               5           Valley City             NaN           DISK    ND
# 6               6           Crater Lake             NaN         CIRCLE    CA
# 7               7                  Alma             NaN           DISK    MI
# 8               8               Eklutna             NaN          CIGAR    AK
# 9               9               Hubbard             NaN       CYLINDER    OR
# 10             10               Fontana             NaN          LIGHT    CA
# ...

# %%
mydata.dropna(thresh=5).shape
# Out:
# (15971, 6)

# %%
mydata.dropna(thresh=7)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, City, Colors Reported, Shape Reported, State, Time]
# Index: []

# %%
mydata.dropna(thresh=7).shape
# Out:
# (0, 6)

# %%
mydata.fillna(10)
#for assigning values to null values
# Out:
#        Unnamed: 0                  City Colors Reported Shape Reported State  \
# 0               0                Ithaca              10       TRIANGLE    NY
# 1               1           Willingboro              10          OTHER    NJ
# 2               2               Holyoke              10           OVAL    CO
# 3               3               Abilene              10           DISK    KS
# 4               4  New York Worlds Fair              10          LIGHT    NY
# 5               5           Valley City              10           DISK    ND
# 6               6           Crater Lake              10         CIRCLE    CA
# 7               7                  Alma              10           DISK    MI
# 8               8               Eklutna              10          CIGAR    AK
# 9               9               Hubbard              10       CYLINDER    OR
# 10             10               Fontana              10          LIGHT    CA
# ...

# %%
#for imputing data
# to fill missing value fill(0 or mean or any value or more repeated values(mode))
from sklearn.preprocessing import Imputer

# %%
C:\Users\dell\Desktop\ML\DataSets-master

# %%
imp.fit_transform(mydata)
#error due to data is in string form
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-188cb04cc18d> in <module>()
# ----> 1 imp.fit_transform(mydata)
#       2 #error due to data is in string form
#
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     492         if y is None:
#     493             # fit method of arity 1 (unsupervised transformation)
# --> 494             return self.fit(X, **fit_params).transform(X)
#     495         else:
#     496             # fit method of arity 2 (supervised transformation)
#
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\preprocessing\imputation.py in fit(self, X, y)
#     154         if self.axis == 0:
#     155             X = check_array(X, accept_sparse='csc', dtype=np.float64,
# --> 156                             force_all_finite=False)
#     157
# ...
